# %% [markdown]
# # Predicting the condition of water wells in Tanzania

# %% [markdown]
# ![tanzania_map.jpg](attachment:tanzania_map.jpg)
#
# <img src=”tanzania_map.jpg” width=”XXX” height=”XXX”>

# %% [markdown]
# ### Data Preparation
